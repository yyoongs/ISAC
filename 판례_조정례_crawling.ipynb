# %%
import time
from bs4 import BeautifulSoup

# %%
import requests


headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36"}

def download(method, url, params = None, data = None, headers = None, wait = 1, maxretries = 3):
    """
    This function 'download's the html from the input url
    """
    try:
        resp = requests.request(method, url, params=params, data=data, headers=headers)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as e:
        if 500 <= e.response.status_code < 600 and maxretries > 0:
            time.sleep(wait)
            print("Error code:", e.response.status_code, "/// Retry num:", maxretries)
            resp = download(method, url, params, data, headers, timeout, maxretries-1)
        else:
            print(e.response.status_code)
            print(e.response.reason)
    return resp

# %%
baseURL = "http://www.ccn.go.kr"
url = baseURL + '/contents/include.ccn?gSiteCode=2&gMenuCode=4&nMenuCode=44&mPart=&startCount='
# 페이지 count를 10 증가시키면 페이지 넘어감

# %%
db = list()
pageCount = 0

try:
    while True:
        html = download("get", url+str(pageCount)) # html download
        dom = BeautifulSoup(html.text,"lxml") # dom tree 구성
        
        if(len(dom.select("table.boardList > tbody > tr")) ==0):
            raise StopIteration
        
        for tr in dom.select("table.boardList > tbody > tr"):

            temp = dict()
            temp['index'] = tr.select_one("td:nth-of-type(1)").text
            temp['category'] = tr.select_one("td:nth-of-type(2)").text
            temp['code'] = tr.select_one("td:nth-of-type(3)").text
            temp['title'] = tr.select_one("td:nth-of-type(4)").text
            temp['date'] = tr.select_one("td:nth-of-type(5)").text

        #             subURL = baseURL + tr.select_one("td:nth-of-type(4) > a")['href']
        #             subHTML = download("get",subURL)
        #             subDOM = BeautifulSoup(subHTML.text,'lxml')
        #             temp['contents'] = subDOM.select_one("div.autocounsel_last_box ul li").text.strip()
            db.append(temp)

        pageCount +=10
            
except:
    for db_item in db:
        print(db_item,"\n\n\n")
    print(len(db))
    # 리스트 속 아이템 출력
# Out:
# {'index': '1', 'category': '기타서비스', 'code': '기타서비스', 'title': '2018 의료 분쟁조정 사례집', 'date': '2019.07.09'}
#
#
#
# {'index': '2', 'category': '기타서비스', 'code': '기타서비스', 'title': '2018 서비스·집단 분쟁조정 사례집', 'date': '2019.07.09'}
#
#
#
# {'index': '3', 'category': '기타서비스', 'code': '기타서비스', 'title': '2018 물품 분쟁조정 사례집', 'date': '2019.07.09'}
#
#
#
# {'index': '4', 'category': '의료서비스', 'code': '의료서비스', 'title': '폐암 진단 지연에 따른 손해배상 요구', 'date': '2019.07.08'}
#
#
#
# {'index': '5', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '수리 불가한 스마트폰 구입대금 환급 등 요구', 'date': '2019.07.08'}
#
#
#
# {'index': '6', 'category': '의료서비스', 'code': '의료서비스', 'title': '수지 골절수술 후 후유장해 발생에 따른 손해배상 요구', 'date': '2019.07.04'}
#
#
#
# {'index': '7', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '측면 부풀음 현상 발생한 타이어의 구입가 환급 요구', 'date': '2019.07.04'}
#
#
#
# {'index': '8', 'category': '식료품·기호품', 'code': '식료품·기호품', 'title': '배송받은 포도 상태 불량으로 인한 환급 요구', 'date': '2019.07.03'}
#
#
#
# {'index': '9', 'category': '가사용품', 'code': '가사용품', 'title': '문짝 처짐이 발생한 의류건조기 대금 환급 요구', 'date': '2019.06.27'}
#
#
#
# {'index': '10', 'category': '가사용품', 'code': '가사용품', 'title': '하자있는 소파 구입대금 환급 요구', 'date': '2019.06.27'}
#
#
#
# {'index': '11', 'category': '가사용품', 'code': '가사용품', 'title': '하자 있는 식탁의 구입대금 환급 및 치료비 등 손해배상 요구', 'date': '2019.06.27'}
#
#
#
# {'index': '12', 'category': '가사용품', 'code': '가사용품', 'title': '정수기 누수로 인하여 손상된 싱크대 및 바닥 장판 손해배상 요구', 'date': '2019.06.27'}
#
#
#
# {'index': '13', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '대여 유아드레스 훼손에 따른 과다 배상비 및 보증금 환급 요구', 'date': '2019.06.27'}
#
#
#
# {'index': '14', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '전자상거래로 구입한 신발 양쪽 가죽차이로 인한 구입대금 환급 요구', 'date': '2019.06.27'}
#
#
#
# {'index': '15', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '계약 내용과 다른 정화조 설치로 인한 대금 환급 요구', 'date': '2019.06.27'}
#
#
#
# {'index': '16', 'category': '금융', 'code': '금융', 'title': '발행일이 기재되지 않았다며 사용 거절된 쇼핑몰 이용 상품권 사용인정 요구', 'date': '2019.06.27'}
#
#
#
# {'index': '17', 'category': '금융', 'code': '금융', 'title': '과다한 위약금을 공제하는 유사투자자문서비스 환급금 추가 지급 요구', 'date': '2019.06.26'}
#
#
#
# {'index': '18', 'category': '금융', 'code': '금융', 'title': '갑상선고주파술에 대한 수술보험금 지급 요구', 'date': '2019.06.26'}
#
#
#
# {'index': '19', 'category': '기타서비스', 'code': '기타서비스', 'title': '주식투자정보서비스 해지 환급금 지급 요구', 'date': '2019.06.26'}
#
#
#
# {'index': '20', 'category': '금융', 'code': '금융', 'title': '자궁경부봉축술에 대한 수술보험금 및 실손의료비 지급 요구', 'date': '2019.06.26'}
#
#
#
# {'index': '21', 'category': '금융', 'code': '금융', 'title': '일산화탄소 중독 치료 중 사망한 사고에 대한 재해장해보험금 및 재해사망보험금 지급 요구', 'date': '2019.05.07'}
#
#
#
# {'index': '22', 'category': '기타서비스', 'code': '기타서비스', 'title': '결혼중개서비스 계약위반에 따른 가입비 환급 요구', 'date': '2018.12.21'}
#
#
#
# {'index': '23', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '교부하지 않은 계약서를 근거로 부당 청구된 통신요금 조정 요구', 'date': '2018.12.21'}
#
#
#
# {'index': '24', 'category': '기타서비스', 'code': '기타서비스', 'title': '예식장 및 연회시설 이용계약 해제에 따른 위약금 조정 요구', 'date': '2018.12.21'}
#
#
#
# {'index': '25', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '주차장 관리 미흡으로 주차 도중 사고 발생한 차량의 수리비 배상 요구', 'date': '2018.12.13'}
#
#
#
# {'index': '26', 'category': '기타서비스', 'code': '기타서비스', 'title': '모바일 이성중개서비스 계정의 영구정지처분 철회 요구', 'date': '2018.12.13'}
#
#
#
# {'index': '27', 'category': '스포츠·레저·취미용품', 'code': '스포츠·레저·취미용품', 'title': '볼링장 내에서 발생한 신체 상해에 대한 손해배상 요구', 'date': '2018.12.13'}
#
#
#
# {'index': '28', 'category': '기타서비스', 'code': '기타서비스', 'title': '결혼준비대행서비스 웨딩플래너 변경으로 인한 계약금 환급 요구', 'date': '2018.12.13'}
#
#
#
# {'index': '29', 'category': '스포츠·레저·취미용품', 'code': '스포츠·레저·취미용품', 'title': '승마 트레킹 중 낙마 사고로 발생한 손해 배상 요구', 'date': '2018.12.13'}
#
#
#
# {'index': '30', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '주거지 통화품질 불량으로 인한 위면해지 및 손해배상 요구', 'date': '2018.12.13'}
#
#
#
# {'index': '31', 'category': '의료서비스', 'code': '의료서비스', 'title': '보철 제작시 금 함량 미달로 단기간에 발치받은 데 따른 손해배상 요구', 'date': '2018.11.22'}
#
#
#
# {'index': '32', 'category': '의료서비스', 'code': '의료서비스', 'title': '낙상 후 골절 진단지연에 따른 손해배상 요구', 'date': '2018.11.22'}
#
#
#
# {'index': '33', 'category': '의료서비스', 'code': '의료서비스', 'title': '백내장 수술 중 후낭파열로 시각장해 발생에 따른 손해배상 요구', 'date': '2018.11.22'}
#
#
#
# {'index': '34', 'category': '의료서비스', 'code': '의료서비스', 'title': '대동맥치환술 후 뇌병변 장애에 따른 손해배상 요구', 'date': '2018.11.22'}
#
#
#
# {'index': '35', 'category': '의료서비스', 'code': '의료서비스', 'title': '요관 결석제거술 중 요관손상에 따른 손해배상 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '36', 'category': '의료서비스', 'code': '의료서비스', 'title': '심장질환에 대한 부적절한 처치로 사망한데 따른 손해배상 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '37', 'category': '기타서비스', 'code': '기타서비스', 'title': '헬스장 이용 계약 해지 및 잔여 이용료 환급 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '38', 'category': '기타서비스', 'code': '기타서비스', 'title': '실측오류로 잘못 시공된 신발장 계약 해제 및 환급 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '39', 'category': '기타서비스', 'code': '기타서비스', 'title': '상판 까짐 하자 발생하는 화산석 식탁 환급 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '40', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '조명설치 계약 후 하자 다발 및 수리불이행에 따른 계약대금 환급 및 원상복구 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '41', 'category': '기타서비스', 'code': '기타서비스', 'title': '개인 사정으로 예약 취소한 대여 차량 이용대금 환급 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '42', 'category': '기타서비스', 'code': '기타서비스', 'title': '사전 고지없이 청구하는 소파 계약 해제 위약금 반환 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '43', 'category': '가사용품', 'code': '가사용품', 'title': '성능 및 광고에 문제가 있는 냉난방기 환급 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '44', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '여행상품 계약 해제에 따른 대금 환급 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '45', 'category': '기타서비스', 'code': '기타서비스', 'title': '이사업체의 이사예정 전날 일방적인 계약 파기에 따른 손해배상 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '46', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '국외여행 중 발생한 상해로 인한 손해배상 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '47', 'category': '기타서비스', 'code': '기타서비스', 'title': '택배 의뢰 후 분실된 물품의 손해배상 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '48', 'category': '기타서비스', 'code': '기타서비스', 'title': '호텔 주차장에 주차한 차량의 파손에 대한 손해배상 요구', 'date': '2018.11.12'}
#
#
#
# {'index': '49', 'category': '기타서비스', 'code': '기타서비스', 'title': '숙박예정일 1일 전 취소한 펜션 계약 이용대금 환급 요구', 'date': '2018.11.01'}
#
#
#
# {'index': '50', 'category': '가사용품', 'code': '가사용품', 'title': '유튜브 서비스 이용이 중단된 스마트 TV 배상 요구', 'date': '2018.10.31'}
#
#
#
# {'index': '51', 'category': '기타서비스', 'code': '기타서비스', 'title': '임신으로 인한 요가 강습 계약 해지에 따른 환급 요구', 'date': '2018.10.31'}
#
#
#
# {'index': '52', 'category': '의료서비스', 'code': '의료서비스', 'title': '피부시술계약 해지에 따른 잔여 시술비용 환급 요구', 'date': '2018.10.25'}
#
#
#
# {'index': '53', 'category': '의료서비스', 'code': '의료서비스', 'title': '임플란트 시술 실패에 따른 손해배상 요구', 'date': '2018.10.25'}
#
#
#
# {'index': '54', 'category': '의료서비스', 'code': '의료서비스', 'title': '대장 용종절제술 후 천공 발생에 따른 손해배상 요구', 'date': '2018.10.23'}
#
#
#
# {'index': '55', 'category': '의료서비스', 'code': '의료서비스', 'title': '난소낭종절제술 후 난소파열 및 혈복강 발생에 따른 손해배상 요구', 'date': '2018.10.23'}
#
#
#
# {'index': '56', 'category': '교육서비스', 'code': '교육서비스', 'title': '인터넷 투자정보서비스 이용계약 해지에 따른 대금 환급 요구', 'date': '2018.10.23'}
#
#
#
# {'index': '57', 'category': '의료서비스', 'code': '의료서비스', 'title': '고환농양 치료 후 염증 재발에 따른 손해배상 요구', 'date': '2018.10.23'}
#
#
#
# {'index': '58', 'category': '의료서비스', 'code': '의료서비스', 'title': '흉선종 진단 지연에 따른 손해배상 요구', 'date': '2018.10.23'}
#
#
#
# {'index': '59', 'category': '의료서비스', 'code': '의료서비스', 'title': '비강내 이물질 제거 실패로 기도 흡인된데 따른 손해배상 요구', 'date': '2018.10.22'}
#
#
#
# {'index': '60', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '계약 내용과 다르게 설치된 폴딩도어 배상 요구', 'date': '2018.10.22'}
#
#
#
# {'index': '61', 'category': '기타서비스', 'code': '기타서비스', 'title': '품질보증기간 이내에 훼손된 BBQ 가제보B 천장 무상수리 요구', 'date': '2018.10.22'}
#
#
#
# {'index': '62', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '차량 과잉 정비에 따른 배상 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '63', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '보일러 누수에 따른 배상 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '64', 'category': '기타서비스', 'code': '기타서비스', 'title': '방수팩 하자로 인한 스마트폰 수리비 배상 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '65', 'category': '기타서비스', 'code': '기타서비스', 'title': '스마트폰 하자에 따른 환급 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '66', 'category': '기타서비스', 'code': '기타서비스', 'title': '전자상거래로 구매한 사운드 카드 구매 취소에 따른 구입대금 환급 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '67', 'category': '가사용품', 'code': '가사용품', 'title': '노트북의 품질보증기간 오안내로 인한 구입대금 환급 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '68', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '상이한 인테리어 공사 견적비용에 따른 현장실측비 환급 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '69', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '인테리어 시공계약 불이행에 따른 재시공 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '70', 'category': '기타서비스', 'code': '기타서비스', 'title': '해외구매대행으로 주문한 중고 부츠 청약철회 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '71', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '누수탐지 불완전이행 및 보일러 부품 훼손으로 인한 누수에 따른 손해배상 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '72', 'category': '기타서비스', 'code': '기타서비스', 'title': '회수 지연으로 분실된 캐리어 구매대금 환급 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '73', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '오피스텔 허위과장 광고 등 기망행위에 대한 손해배상 요구', 'date': '2018.10.19'}
#
#
#
# {'index': '74', 'category': '기타서비스', 'code': '기타서비스', 'title': '의료분쟁조정 사례집', 'date': '2017.06.09'}
#
#
#
# {'index': '75', 'category': '기타서비스', 'code': '기타서비스', 'title': '일반집단분쟁조정 사례집', 'date': '2017.06.09'}
#
#
#
# {'index': '76', 'category': '의료서비스', 'code': '의료서비스', 'title': '직장유암종에 대한 암 보험금 지급 요구', 'date': '2017.01.26'}
#
#
#
# {'index': '77', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '콘도 회원권 시설관리보증금 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '78', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '초청비자 신청대행수수료 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '79', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '차량 도장불량으로 인한 구입가 환급 등 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '80', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '중고차 침수 이력 미고지로 인한 손해배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '81', 'category': '기타서비스', 'code': '기타서비스', 'title': '중고 컨테이너 누수로 인한 하자 보수 등 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '82', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '주방가구 시공 지연으로 인한 손해배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '83', 'category': '가사용품', 'code': '가사용품', 'title': '전자상거래로 구입한 김치냉장고 주문 취소로 인한 손해배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '84', 'category': '가사용품', 'code': '가사용품', 'title': '인터넷 쇼핑몰 광고와 색상이 다른 카메라 삼각대 구입대금 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '85', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '오피스텔 분양계약 해제에 따른 계약금 반환 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '86', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '아파트 혐오시설로 인한 계약금 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '87', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '신혼여행 도중 발생한 상해에 대한 손해배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '88', 'category': '기타서비스', 'code': '기타서비스', 'title': '불명확한 표시·광고로 인하여 응모기회 상실한 이벤트 보상 지급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '89', 'category': '기타서비스', 'code': '기타서비스', 'title': '무료 체험 기간 경과 후 반품 신청한 안경 구입대금 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '90', 'category': '기타서비스', 'code': '기타서비스', 'title': '구입 후 15일 이내 폐사한 고양이 구입대금 환급 등 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '91', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '구매대행으로 구입한 스마트폰 구입가 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '92', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '견인 장비 사용료 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '93', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '현지 공항 사정으로 이행하지 못한 여행 일정에 대한 보상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '94', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '항공기 운항 지연에 따른 손해배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '95', 'category': '금융', 'code': '금융', 'title': '특약보험료를 포함한 만기급여금 지급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '96', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '지적장애 1급의 장애인이 체결한 계약에 기한 채무부존재 인정 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '97', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '전화권유판매로 체결된 휴대폰 매매계약에 관한 청약철회에 따른 채무부존재 인정 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '98', 'category': '교육서비스', 'code': '교육서비스', 'title': '음악 자유이용권의 지급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '99', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '유효기간 미고지로 소멸된 적립금 지급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '100', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '여행사의 과실로 출발하지 못한 국외여행 손해배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '101', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '여행 출발 2개월 전에 해제한 국외여행계약의 계약금 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '102', 'category': '금융', 'code': '금융', 'title': '상조공제금 지급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '103', 'category': '금융', 'code': '금융', 'title': '상조계약 해제에 따른 환급금 지급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '104', 'category': '금융', 'code': '금융', 'title': '상조계약 해제에 따른 환급금 지급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '105', 'category': '금융', 'code': '금융', 'title': '사실혼 배우자의 사망에 따른 보험금 지급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '106', 'category': '금융', 'code': '금융', 'title': '부당 인상한 주식매매수수료 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '107', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '동일 고장이 3회 발생한 스마트폰의 구입대금 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '108', 'category': '교육서비스', 'code': '교육서비스', 'title': '도서 구입 포인트 적립 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '109', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '녹 발생 및 수리 흔적 있는 차량의 교환 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '110', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '공항 화재로 인한 항공기 운항 취소에 따른 손해배상 등 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '111', 'category': '기타서비스', 'code': '기타서비스', 'title': '해외구매대행업체를 통해 구입한 장난감의 미배송으로 인한 구입대금 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '112', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '항공편 지연으로 인한 손해배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '113', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '항공기 운항일정 변경통지 미이행에 따른 손해 배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '114', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '항공기 결항으로 인한 호텔 예약 취소에 따른 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '115', 'category': '기타서비스', 'code': '기타서비스', 'title': '하자가 개선되지 않는 승용완구에 대한 구입대금 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '116', 'category': '기타서비스', 'code': '기타서비스', 'title': '전자상거래로 구입한 자전거 트레일러 받침대 반품 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '117', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '고속버스 자유이용권 약관 미안내에 따른 손해배상청구', 'date': '2016.06.21'}
#
#
#
# {'index': '118', 'category': '기타서비스', 'code': '기타서비스', 'title': '유효기간 미고지로 소멸된 적립금 지급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '119', 'category': '기타서비스', 'code': '기타서비스', 'title': '예매 시스템 오류로 인해 발생한 손해 배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '120', 'category': '교육서비스', 'code': '교육서비스', 'title': '시야제한 발생에 따른 공연 관람 불편에 대한 일부대금 환급 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '121', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '수하물 분실에 대한 배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '122', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '배송 중 과일 부패로 인한 손해배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '123', 'category': '기타서비스', 'code': '기타서비스', 'title': '미닫이문에 의한 손가락 부상 치료비 배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '124', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '가이드 불성실 및 광고와 다른 계약내용 이행으로 인한 손해배상 요구', 'date': '2016.06.21'}
#
#
#
# {'index': '125', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '전자상거래로 구입한 의류의 청약철회 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '126', 'category': '기타서비스', 'code': '기타서비스', 'title': '전자상거래로 구매한 운동화의 벨크로 불량에 따른 계약해제 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '127', 'category': '가사용품', 'code': '가사용품', 'title': '전시회에서 구입한 스마트 발란스 휠의 청약철회 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '128', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '세탁 후 갑피 변형된 스니커즈에 대한 배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '129', 'category': '금융', 'code': '금융', 'title': '보험사의 잘못된 안내로 인한 렌터카 이용에 대한 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '130', 'category': '가사용품', 'code': '가사용품', 'title': '노트북컴퓨터 메인보드 하자의 무상수리 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '131', 'category': '가사용품', 'code': '가사용품', 'title': '노트북 배터리 불량에 따른 무상교체 요구 건', 'date': '2016.06.14'}
#
#
#
# {'index': '132', 'category': '가사용품', 'code': '가사용품', 'title': '해외이사 과정에서 파손된 물품에 대한 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '133', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '항공기 운항일정 변경통지 미이행에 따른 손해 배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '134', 'category': '기타서비스', 'code': '기타서비스', 'title': '인터넷 서비스 이용계약상 주소지 이전 미처리에 따른 요금 환급 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '135', 'category': '금융', 'code': '금융', 'title': '정신질환 치료 중 자살에 대한 재해사망보험금 지급 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '136', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '전자상거래로 주문한 유니폼에 대한 환급 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '137', 'category': '가사용품', 'code': '가사용품', 'title': '사용한 흔적이 있는 휴대폰의 교환 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '138', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '아파트 결로 하자 발생에 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '139', 'category': '의료서비스', 'code': '의료서비스', 'title': '충수염 수술 후 발생한 복강 내 출혈에 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '140', 'category': '의료서비스', 'code': '의료서비스', 'title': '회전근개 수술 후 발생한 감염에 대한 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '141', 'category': '의료서비스', 'code': '의료서비스', 'title': 'CT 검사 직후 사망에 대한 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '142', 'category': '의료서비스', 'code': '의료서비스', 'title': '병원 이송 중 조치소홀에 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '143', 'category': '의료서비스', 'code': '의료서비스', 'title': '인공관절치환술 후 장해 발생에 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '144', 'category': '의료서비스', 'code': '의료서비스', 'title': '상안검성형술 후 눈꺼풀 함몰 및 안검하수 발생에 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '145', 'category': '의료서비스', 'code': '의료서비스', 'title': '비후성반흔에 대한 레이저 시술 후 상태악화에 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '146', 'category': '의료서비스', 'code': '의료서비스', 'title': '백내장 수술시 다초점렌즈 삽입에 따른 공제금 지급 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '147', 'category': '의료서비스', 'code': '의료서비스', 'title': '뇌동맥류 수술 후 사망에 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '148', 'category': '의료서비스', 'code': '의료서비스', 'title': '슬관절 내반슬 수술 후 외반슬에 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '149', 'category': '의료서비스', 'code': '의료서비스', 'title': '자궁내막암으로 림프절제술 중 신정맥 손상에 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '150', 'category': '의료서비스', 'code': '의료서비스', 'title': '보철치료 후 재치료를 받은데 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '151', 'category': '의료서비스', 'code': '의료서비스', 'title': '돌출입 교정치료 실패로 수술이 필요한 데 대한 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '152', 'category': '의료서비스', 'code': '의료서비스', 'title': '척추성형술 후 장천공 및 복막염으로 사망한 데 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '153', 'category': '의료서비스', 'code': '의료서비스', 'title': '심근경색의 부적절한 처치로 사망한 데 따른 손해배상 요구', 'date': '2016.06.14'}
#
#
#
# {'index': '154', 'category': '의료서비스', 'code': '의료서비스', 'title': '다이어트약 복용 후 급성 녹내장 발생에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '155', 'category': '의료서비스', 'code': '의료서비스', 'title': '한방 가슴성형 시술 후 효과미흡에 따른 진료비 환급 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '156', 'category': '의료서비스', 'code': '의료서비스', 'title': '가와사키병 진단 지연에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '157', 'category': '의료서비스', 'code': '의료서비스', 'title': '뇌경색 진단지연에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '158', 'category': '의료서비스', 'code': '의료서비스', 'title': '흉추혈관종을 유방암 골전이로 오진한데 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '159', 'category': '의료서비스', 'code': '의료서비스', 'title': '제왕절개술 후 수술부위 혈종에 대한 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '160', 'category': '의료서비스', 'code': '의료서비스', 'title': '체외충격파쇄석술 후 합병증 발생에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '161', 'category': '의료서비스', 'code': '의료서비스', 'title': '전립선절제술 후 역행성 사정에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '162', 'category': '의료서비스', 'code': '의료서비스', 'title': '모발이식술 후 효과미흡 및 감각이상에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '163', 'category': '의료서비스', 'code': '의료서비스', 'title': '피부과 레이저 시술 계약 해지에 따른 진료비 환급 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '164', 'category': '의료서비스', 'code': '의료서비스', 'title': '알로푸리놀 복용 후 과민반응으로 사망에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '165', 'category': '의료서비스', 'code': '의료서비스', 'title': '도트필링 시술 후 함몰흉터 발생에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '166', 'category': '의료서비스', 'code': '의료서비스', 'title': '관상동맥우회로술 후 감염 발생에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '167', 'category': '의료서비스', 'code': '의료서비스', 'title': '장골 동맥 폐색으로 하지 절단에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '168', 'category': '의료서비스', 'code': '의료서비스', 'title': '코성형술 후 흉터 발생에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '169', 'category': '의료서비스', 'code': '의료서비스', 'title': '양악수술 후 부작용에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '170', 'category': '의료서비스', 'code': '의료서비스', 'title': '안면거상술 후 귀변형 등 부작용에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '171', 'category': '의료서비스', 'code': '의료서비스', 'title': '쌍꺼풀 수술 및 코 성형술 후 부작용 발생에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '172', 'category': '의료서비스', 'code': '의료서비스', 'title': '유방확대수술 후 합병증 발생에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '173', 'category': '의료서비스', 'code': '의료서비스', 'title': '폐쇄병동 입원 중 추락사고에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '174', 'category': '의료서비스', 'code': '의료서비스', 'title': '알코올 의존증 치료 중 사망에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '175', 'category': '의료서비스', 'code': '의료서비스', 'title': '비중격비성형술 후 부작용에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '176', 'category': '의료서비스', 'code': '의료서비스', 'title': '보청기 제작과정 중 고막천공 발생에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '177', 'category': '의료서비스', 'code': '의료서비스', 'title': '위암수술 후 위장관 출혈로 사망에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '178', 'category': '의료서비스', 'code': '의료서비스', 'title': '두피 열상 봉합부위 이물질 잔존에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '179', 'category': '의료서비스', 'code': '의료서비스', 'title': '중심정맥관 삽입 후 동맥손상으로 사망에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '180', 'category': '의료서비스', 'code': '의료서비스', 'title': '대장내시경 중 장 천공에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '181', 'category': '의료서비스', 'code': '의료서비스', 'title': '충수염 진단지연으로 개복수술에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '182', 'category': '의료서비스', 'code': '의료서비스', 'title': '신장이식술 실패에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '183', 'category': '의료서비스', 'code': '의료서비스', 'title': '회장루 복원술 후 재수술에 따른 손해배상 요구', 'date': '2015.09.09'}
#
#
#
# {'index': '184', 'category': '의료서비스', 'code': '의료서비스', 'title': '담도암 간전이 수술 후 출혈로 사망에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '185', 'category': '의료서비스', 'code': '의료서비스', 'title': '장허혈로 입원치료 중 사망에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '186', 'category': '의료서비스', 'code': '의료서비스', 'title': '경동맥 손상으로 뇌손상 발생에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '187', 'category': '의료서비스', 'code': '의료서비스', 'title': '채용건강검진 결과 미통보로 간암 진단이 지연된데 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '188', 'category': '의료서비스', 'code': '의료서비스', 'title': '임의 발치에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '189', 'category': '의료서비스', 'code': '의료서비스', 'title': '임플란트의 반복 탈락에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '190', 'category': '의료서비스', 'code': '의료서비스', 'title': '신경치료 후 치아 파절에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '191', 'category': '의료서비스', 'code': '의료서비스', 'title': '임플란트 식립 후 재식립 필요에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '192', 'category': '의료서비스', 'code': '의료서비스', 'title': '교정치료 후 충치로 인한 발치에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '193', 'category': '의료서비스', 'code': '의료서비스', 'title': '임플란트 시술 후 임플란트 주위염 및 지각이상에 대한 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '194', 'category': '의료서비스', 'code': '의료서비스', 'title': '치아 교정 후 부정교합에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '195', 'category': '의료서비스', 'code': '의료서비스', 'title': '당뇨망막병증 수술 후 시각장애에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '196', 'category': '의료서비스', 'code': '의료서비스', 'title': '좌안 이물질 제거술 중 각막 천공에 따른 손해배상 요구', 'date': '2015.09.08'}
#
#
#
# {'index': '197', 'category': '의료서비스', 'code': '의료서비스', 'title': '망막박리수술 후 실명에 따른 손해배상 요구', 'date': '2015.09.07'}
#
#
#
# {'index': '198', 'category': '의료서비스', 'code': '의료서비스', 'title': '안내염 진단지연으로 실명에 따른 손해배상 요구', 'date': '2015.09.07'}
#
#
#
# {'index': '199', 'category': '의료서비스', 'code': '의료서비스', 'title': '손목 골절 수술 후 후유장해에 따른 손해배상 요구', 'date': '2015.09.07'}
#
#
#
# {'index': '200', 'category': '의료서비스', 'code': '의료서비스', 'title': '수술 후 칸디다 감염에 따른 손해배상 요구', 'date': '2015.09.07'}
#
#
#
# {'index': '201', 'category': '의료서비스', 'code': '의료서비스', 'title': '척추 신경성형술 효과 미흡에 따른 손해배상 요구', 'date': '2015.09.07'}
#
#
#
# {'index': '202', 'category': '의료서비스', 'code': '의료서비스', 'title': '상완골 골절 수술 후 재수술에 따른 손해배상 요구', 'date': '2015.09.07'}
#
#
#
# {'index': '203', 'category': '의료서비스', 'code': '의료서비스', 'title': '경추 수술 후 편마비 발생에 따른 손해배상 요구', 'date': '2015.09.07'}
#
#
#
# {'index': '204', 'category': '의료서비스', 'code': '의료서비스', 'title': '척추 골절 수술 후 간경색으로 사망한데 따른 손해배상 요구', 'date': '2015.09.07'}
#
#
#
# {'index': '205', 'category': '의료서비스', 'code': '의료서비스', 'title': '추간판탈출증 수술 후 장애에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '206', 'category': '의료서비스', 'code': '의료서비스', 'title': '뇌수막종 수술 후 양안 실명에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '207', 'category': '의료서비스', 'code': '의료서비스', 'title': '추간판탈출증 수술 후 재수술을 받은 데 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '208', 'category': '의료서비스', 'code': '의료서비스', 'title': '척추 유합술 후 후유장애에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '209', 'category': '의료서비스', 'code': '의료서비스', 'title': '뇌동맥류 결찰술 후 사망에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '210', 'category': '의료서비스', 'code': '의료서비스', 'title': '척추 시술 및 물리치료 후 증상악화에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '211', 'category': '의료서비스', 'code': '의료서비스', 'title': '뇌출혈 수술 후 재출혈로 장해 발생에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '212', 'category': '의료서비스', 'code': '의료서비스', 'title': '운동부하검사 후 심근경색증으로 사망한데 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '213', 'category': '의료서비스', 'code': '의료서비스', 'title': '장염 치료 중 사망에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '214', 'category': '의료서비스', 'code': '의료서비스', 'title': '알로푸리놀 약 복용 후 과민반응 증후군 발생에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '215', 'category': '의료서비스', 'code': '의료서비스', 'title': '관상동맥중재술 후 사망에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '216', 'category': '의료서비스', 'code': '의료서비스', 'title': '위장염 치료 중 괴사성 근막염으로 사망에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '217', 'category': '의료서비스', 'code': '의료서비스', 'title': '관상동맥중재술 중 사망에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '218', 'category': '의료서비스', 'code': '의료서비스', 'title': '심혈관조영술 후 사망에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '219', 'category': '의료서비스', 'code': '의료서비스', 'title': '부적절한 담도패혈증 치료로 사망함에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '220', 'category': '의료서비스', 'code': '의료서비스', 'title': '흡인으로 기도 폐색되어 사망함에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '221', 'category': '의료서비스', 'code': '의료서비스', 'title': '폐암 진단지연에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '222', 'category': '의료서비스', 'code': '의료서비스', 'title': '림프종 진단지연에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '223', 'category': '의료서비스', 'code': '의료서비스', 'title': '간암 진단 지연에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '224', 'category': '의료서비스', 'code': '의료서비스', 'title': '담췌관조영술 후 천공으로 사망함에 따른 손해배상 요구', 'date': '2015.09.03'}
#
#
#
# {'index': '225', 'category': '기타서비스', 'code': '기타서비스', 'title': '차량 인도 시부터 단차 있고 사양 미적용 된 ○○○ 차량 교환 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '226', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '도장불량 등 여러 하자로 인한 ○○○차량 교환 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '227', 'category': '가사용품', 'code': '가사용품', 'title': '렌탈정수기 설치 하자로 입은 누수피해에 대한 손해배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '228', 'category': '가사용품', 'code': '가사용품', 'title': '과다 청구된 정수기 렌탈료 환급 및 계약 내용 이행 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '229', 'category': '기타서비스', 'code': '기타서비스', 'title': '분실된 휴대폰으로 결제된 유료 컨텐츠 요금 취소 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '230', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '휴대폰 수리과정에 발생한 데이터 삭제에 따른 손해배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '231', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '주문과 다르게 제작된 신사복 세트 대금 환급 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '232', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '온라인으로 6회에 걸쳐 주문한 의류 중 일부 상품에 대한 반품 및 환불 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '233', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '항공기 환승시간 부족으로 환승하지 못한 피해에 대한 손해배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '234', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '지하철 승차시 입은 부상에 대한 배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '235', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '고속버스 좌석 위 선반에 놓여둔 배낭 등 도난에 따른 손해배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '236', 'category': '기타서비스', 'code': '기타서비스', 'title': '구입 후 3일만에 폐사한 앵무새 환급 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '237', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '잘못된 의류 수선에 대한 손해배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '238', 'category': '의료서비스', 'code': '의료서비스', 'title': '화장품 부작용으로 인한 구입가 환급 및 치료비 배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '239', 'category': '의료서비스', 'code': '의료서비스', 'title': '안마의자 매매 계약 해제 및 위약금 조정 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '240', 'category': '가사용품', 'code': '가사용품', 'title': '제품 파손으로 인하여 침수된 방수카메라의 교환 또는 환급 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '241', 'category': '기타서비스', 'code': '기타서비스', 'title': '항공기 내에서 입은 상해에 대한 손해배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '242', 'category': '기타서비스', 'code': '기타서비스', 'title': '질병으로 인한 신혼여행 계약 해제에 따른 환급 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '243', 'category': '교육서비스', 'code': '교육서비스', 'title': '여행 중 발생한 사고로 인한 여행경비 배상 청구', 'date': '2015.08.18'}
#
#
#
# {'index': '244', 'category': '기타서비스', 'code': '기타서비스', 'title': '야외 스파장 이용시 발가락 골절로 인한 손해배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '245', 'category': '기타서비스', 'code': '기타서비스', 'title': '마트 내 무빙워크 이용 중 발생한 사고로 인한 손해배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '246', 'category': '교육서비스', 'code': '교육서비스', 'title': '골프장 선불카드 매매 계약 해제에 따른 매매 대금 환급 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '247', 'category': '기타서비스', 'code': '기타서비스', 'title': '산후조리원에서 감염된 질병에 대한 배상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '248', 'category': '기타서비스', 'code': '기타서비스', 'title': '대리운전기사의 과실로 인한 차량 파손에 대한 보상 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '249', 'category': '기타서비스', 'code': '기타서비스', 'title': '결혼정보서비스 이용계약 중도 해지로 인한 잔여 금액 환급 요구', 'date': '2015.08.18'}
#
#
#
# {'index': '250', 'category': '금융', 'code': '금융', 'title': '축소된  신용카드 부가서비스 취소 요구', 'date': '2015.08.17'}
#
#
#
# {'index': '251', 'category': '금융', 'code': '금융', 'title': '증권방송서비스 이용계약 해지에 따른 잔여 이용대금 환급 요구', 'date': '2015.08.17'}
#
#
#
# {'index': '252', 'category': '금융', 'code': '금융', 'title': '구입한 가방 하자에 따른 할부 항변권 수용 요구', 'date': '2015.08.17'}
#
#
#
# {'index': '253', 'category': '기타서비스', 'code': '기타서비스', 'title': '도시가스 미검침으로 과다 납부한 요금 환급 요구', 'date': '2015.08.17'}
#
#
#
# {'index': '254', 'category': '기타서비스', 'code': '기타서비스', 'title': '주문·제작한 블라인드의 설치 불가에 따른 청약철회 요구', 'date': '2015.08.17'}
#
#
#
# {'index': '255', 'category': '기타서비스', 'code': '기타서비스', 'title': '배수관세척제 사용 후 욕조 배수구 부식에 따른 손해배상 요구', 'date': '2015.08.17'}
#
#
#
# {'index': '256', 'category': '기타서비스', 'code': '기타서비스', 'title': '전자상거래 통해 구입한 조립 가구 하자에 따른 구입가 환급 요구', 'date': '2015.08.17'}
#
#
#
# {'index': '257', 'category': '기타서비스', 'code': '기타서비스', 'title': '주행 중 이상 소음 발생하는 ○○○ 차량 수리 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '258', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '구입 직후 녹이 많이 발생한 차량 무상보증 기간 연장 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '259', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '렌트카 긁힘 등의 피해에 대해 지불한 배상금 환급 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '260', 'category': '가사용품', 'code': '가사용품', 'title': '렌탈 정수기의 소음에 따른 계약 해지 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '261', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '휴대폰 구매 시 포인트 전액 사용 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '262', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '이동전화 해지누락으로 발생한 부당요금 청구 환급 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '263', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '사이즈가 작은 신사화 반품 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '264', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '항공기 운항 지연으로 인한 손해배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '265', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '포장이사 과정에서 훼손된 물품에 대한 손해배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '266', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '포장이사 과정에서 분실된 물품에 대한 손해배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '267', 'category': '기타서비스', 'code': '기타서비스', 'title': '명의도용된 세포보관 서비스 계약 카드수수료 배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '268', 'category': '기타서비스', 'code': '기타서비스', 'title': '잘못된 정보 제공으로 고장난 작동 완구 배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '269', 'category': '기타서비스', 'code': '기타서비스', 'title': '애완용품 샴푸 후 한쪽 눈 실명된 애완견 치료비 등 배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '270', 'category': '기타서비스', 'code': '기타서비스', 'title': '선천적 질병 있는 애완견 인도에 따른 보상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '271', 'category': '기타서비스', 'code': '기타서비스', 'title': '일방적으로 주문 취소된 한우 2세트 보상요구', 'date': '2015.08.13'}
#
#
#
# {'index': '272', 'category': '식료품·기호품', 'code': '식료품·기호품', 'title': '샌드위치 취식 후 발생한 식중독 치료비 및 위자료 배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '273', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '세탁 후 얼룩 발생한 점퍼 구입대금 배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '274', 'category': '의료서비스', 'code': '의료서비스', 'title': '전자상거래를 통해 구입한 기능성 안경의 청약철회 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '275', 'category': '기타서비스', 'code': '기타서비스', 'title': '사업자 변경에 따른 사우나 이용권 미사용분에 대한 환급 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '276', 'category': '교육서비스', 'code': '교육서비스', 'title': '수리 후 하자 발생 및 음원파일 손상된 mp3 무상수리 및 손해배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '277', 'category': '기타서비스', 'code': '기타서비스', 'title': '헬스장 이용계약 중도 해지에 따른 잔여 이용료 환급 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '278', 'category': '교육서비스', 'code': '교육서비스', 'title': '팬션 이용예정일 1개월 전 계약 해제에 따른 이용대금 전액 환급 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '279', 'category': '기타서비스', 'code': '기타서비스', 'title': '착오로 인한 계약 변경 거부에 따른 대금의 일부 환급 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '280', 'category': '교육서비스', 'code': '교육서비스', 'title': '계약 내용과 다른 해외여행 손해배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '281', 'category': '금융', 'code': '금융', 'title': '해킹으로 게임사이트에서 도용된 문화상품권 캐쉬 배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '282', 'category': '금융', 'code': '금융', 'title': '소셜커머스에서 구입한 쿠폰의 미사용 회차에 대한 환급 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '283', 'category': '교육서비스', 'code': '교육서비스', 'title': '학원수강 계약의 교습개시 전 계약해제에 따른 대금의 환급 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '284', 'category': '교육서비스', 'code': '교육서비스', 'title': '인터넷교육서비스 중도해지에 따른 과다한 위약금 조정 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '285', 'category': '기타서비스', 'code': '기타서비스', 'title': '웨딩 촬영 후 일부 데이터 분실에 따른 손해배상 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '286', 'category': '기타서비스', 'code': '기타서비스', 'title': '예식장 이용 계약의 무기한 연기 후 계약금 반환 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '287', 'category': '기타서비스', 'code': '기타서비스', 'title': '흙소파 품질보증기간 이내 수리불가능 피해에 따른 무상교환 요구', 'date': '2015.08.13'}
#
#
#
# {'index': '288', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '여행 중 발생한 사고로 인한 여행경비 배상 청구', 'date': '2015.04.17'}
#
#
#
# {'index': '289', 'category': '의료서비스', 'code': '의료서비스', 'title': '코 성형 수술시 절골술 미실시에 대한 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '290', 'category': '의료서비스', 'code': '의료서비스', 'title': '피부과 레이저 시술 계약 해지에 따른 진료비 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '291', 'category': '가사용품', 'code': '가사용품', 'title': '효과 없는 불면증 치료 의료기기 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '292', 'category': '교육서비스', 'code': '교육서비스', 'title': '학원수강 계약의 교습개시 전 계약해제에 따른 대금의 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '293', 'category': '교육서비스', 'code': '교육서비스', 'title': '학습지 계약 해지에 따른 대금 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '294', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '하자있는 블랙박스 구입가 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '295', 'category': '가사용품', 'code': '가사용품', 'title': '하자 있는 가방 구입가 환급 및 위자료 배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '296', 'category': '가사용품', 'code': '가사용품', 'title': '프로젝터 수리 지연에 따른 제품 교환 또는 구입가 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '297', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '포장이사 중 파손된 물품 배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '298', 'category': '기타서비스', 'code': '기타서비스', 'title': '구입 후 5일 만에 폐사한 애완고양이 구입가 등 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '299', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '펜션 숙박계약에 관한 청약철회에 따른 이용요금 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '300', 'category': '기타서비스', 'code': '기타서비스', 'title': '채무자에게 통보 없이 공매 처분한 다이아반지 배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '301', 'category': '스포츠·레저·취미용품', 'code': '스포츠·레저·취미용품', 'title': '안내와 달리 제공된 부가서비스를 이유로 한 콘도 분양계약 해제 및 분양대금 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '302', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '체크인 마감 시간 미고지로 인한 항공권 배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '303', 'category': '가사용품', 'code': '가사용품', 'title': '부당청구로 인해 지급한 천체망원경 컨트롤러 교환비용 반환 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '304', 'category': '가사용품', 'code': '가사용품', 'title': '전자도어록 품질 불량으로 인한 배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '305', 'category': '기타서비스', 'code': '기타서비스', 'title': '잘못된 정보 제공으로 고장난 작동 완구 배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '306', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '혼유 사고로 인한 차량 수리비 등 배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '307', 'category': '의료서비스', 'code': '의료서비스', 'title': '자궁경부암 수술 후 급성신부전으로 사망함에 따른 손해배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '308', 'category': '의료서비스', 'code': '의료서비스', 'title': '임플란트 주위염으로 재치료에 따른 손해배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '309', 'category': '의료서비스', 'code': '의료서비스', 'title': '우측 상악 임플란트 실패에 따른 손해배상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '310', 'category': '의료서비스', 'code': '의료서비스', 'title': '임플란트 치료중단에 따른 치료비 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '311', 'category': '식료품·기호품', 'code': '식료품·기호품', 'title': '일방적으로 주문 취소된 한우 2세트 보상 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '312', 'category': '스포츠·레저·취미용품', 'code': '스포츠·레저·취미용품', 'title': '이용하지 않은 PT 계약 해지 및 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '313', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '이사서비스업체의 부당 비용청구에 기한 계약 해지에 따른 계약금 환급 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '314', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '위성방송 이용계약 해지에 따른 위약금 채무 부존재 확인 요구', 'date': '2014.11.14'}
#
#
#
# {'index': '315', 'category': '의료서비스', 'code': '의료서비스', 'title': '위암 결과 미통보에 따른 손해배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '316', 'category': '의료서비스', 'code': '의료서비스', 'title': '운동부하검사 후 심근경색증으로 사망한데 따른 손해배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '317', 'category': '가사용품', 'code': '가사용품', 'title': '옹이 부분이 쉽게 빠지는 원목 서랍장의 구입가 환급 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '318', 'category': '가사용품', 'code': '가사용품', 'title': '온열 기능 불량인 안마의자 교환 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '319', 'category': '가사용품', 'code': '가사용품', 'title': '연수기 이전 설치상 하자로 파손된 욕실 수리 비용 배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '320', 'category': '의료서비스', 'code': '의료서비스', 'title': '레이저 시술 후 색소 침착에 따른 손해배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '321', 'category': '기타서비스', 'code': '기타서비스', 'title': '애완용품 샴푸 후 한쪽 눈 실명된 애완견 치료비 등 배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '322', 'category': '가사용품', 'code': '가사용품', 'title': '안마의자 교환 중 훼손된 마루바닥 배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '323', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '아파트 분양계약 해제에 따른 계약금 환급 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '324', 'category': '의료서비스', 'code': '의료서비스', 'title': '십이지장 천공 진단지연에 따른 손해배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '325', 'category': '의료서비스', 'code': '의료서비스', 'title': '신경치료 후 치아 파절에 따른 손해배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '326', 'category': '의료서비스', 'code': '의료서비스', 'title': '수술 후 칸디다 감염에 따른 손해배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '327', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '수리 후 누유되는 차량 수리비 배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '328', 'category': '스포츠·레저·취미용품', 'code': '스포츠·레저·취미용품', 'title': '소셜커머스를 통한 렌트카 구매계약 해제에 따른 대금 환급 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '329', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '세차장에서 세차 중 파손된 차량용 안테나 수리비 배상 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '330', 'category': '금융', 'code': '금융', 'title': '상조서비스 이용계약 해지에 따른 환급금 지급 요구', 'date': '2014.11.13'}
#
#
#
# {'index': '331', 'category': '기타서비스', 'code': '기타서비스', 'title': '선천적 질병 있는 애완견 인도에 따른 보상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '332', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '세탁 후 얼룩 발생한 점퍼 구입대금 배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '333', 'category': '의료서비스', 'code': '의료서비스', 'title': '석고붕대 후 피부괴사로 장해 발생에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '334', 'category': '의료서비스', 'code': '의료서비스', 'title': '산동제 투여 후 눈 부작용 발생에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '335', 'category': '의료서비스', 'code': '의료서비스', 'title': '사랑니 발치 후 감각이상에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '336', 'category': '의료서비스', 'code': '의료서비스', 'title': '부적절한 교정치료로 재치료가 필요한데 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '337', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '백두산 기획여행 계약의 불완전 이행에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '338', 'category': '가사용품', 'code': '가사용품', 'title': '봉제 불량 및 작동 시 소음 발생하는 안마의자 환급 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '339', 'category': '기타서비스', 'code': '기타서비스', 'title': '백내장 수술 후 시력저하에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '340', 'category': '의료서비스', 'code': '의료서비스', 'title': '목 종물조직검사 후 안검하수 발생에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '341', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '렌터카 사고로 지급한 면책금 환급 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '342', 'category': '의료서비스', 'code': '의료서비스', 'title': '라미네이트 시술 후 탈락에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '343', 'category': '의료서비스', 'code': '의료서비스', 'title': '두피 열상 봉합부위 이물질 잔존에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '344', 'category': '교육서비스', 'code': '교육서비스', 'title': '돌잔치 계약 해제에 따른 계약금 환급 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '345', 'category': '의료서비스', 'code': '의료서비스', 'title': '대장내시경 검사 중 장천공 발생에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '346', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '대리운전 기사의 과실로 파손된 차량 수리기간 중 소요된 교통비 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '347', 'category': '의료서비스', 'code': '의료서비스', 'title': '담도암 간전이 수술 후 출혈로 사망에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '348', 'category': '의료서비스', 'code': '의료서비스', 'title': '뇌경색 진단지연에 따른 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '349', 'category': '가사용품', 'code': '가사용품', 'title': '노트북 구입가 환급 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '350', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '내장공사 시공상 하자로 인한 손해배상 요구', 'date': '2014.09.24'}
#
#
#
# {'index': '351', 'category': '스포츠·레저·취미용품', 'code': '스포츠·레저·취미용품', 'title': '표시·광고와 다른 골프 회원권 무료 숙박 이용 시정 요구', 'date': '2014.07.22'}
#
#
#
# {'index': '352', 'category': '교육서비스', 'code': '교육서비스', 'title': '결혼정보서비스 계약해지에 따른 잔여 대금 환급 요구', 'date': '2014.07.22'}
#
#
#
# {'index': '353', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '국제로밍서비스 장애로 인한 손해배상 요구', 'date': '2014.07.22'}
#
#
#
# {'index': '354', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '단말기 대금 지원 약정 불이행으로 인한 원상회복 요구', 'date': '2014.07.22'}
#
#
#
# {'index': '355', 'category': '의료서비스', 'code': '의료서비스', 'title': '기관식도루 시술 후 사망에 따른 손해배상 요구', 'date': '2014.07.22'}
#
#
#
# {'index': '356', 'category': '의료서비스', 'code': '의료서비스', 'title': '교정치료 후 충치로 인한 발치에 따른 손해배상 요구', 'date': '2014.07.22'}
#
#
#
# {'index': '357', 'category': '의료서비스', 'code': '의료서비스', 'title': '경추수술 후 고정물이탈로 재수술에 따른 손해배상 요구', 'date': '2014.07.22'}
#
#
#
# {'index': '358', 'category': '스포츠·레저·취미용품', 'code': '스포츠·레저·취미용품', 'title': '골프연습장 이용료 계약해지 및 환급 요구', 'date': '2014.07.22'}
#
#
#
# {'index': '359', 'category': '교육서비스', 'code': '교육서비스', 'title': '결혼정보서비스 이용계약 해지에 따른 추가 환급 요구', 'date': '2014.07.22'}
#
#
#
# {'index': '360', 'category': '의료서비스', 'code': '의료서비스', 'title': '회전근개 봉합술 후 재파열에 따른 손해배상 요구', 'date': '2014.07.15'}
#
#
#
# {'index': '361', 'category': '의료서비스', 'code': '의료서비스', 'title': '척추수술 후 하지 마비에 따른 손해배상 요구', 'date': '2014.07.15'}
#
#
#
# {'index': '362', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '차량용 블랙박스 구입대금 환급 요구', 'date': '2014.07.15'}
#
#
#
# {'index': '363', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '질병으로 인한 신혼여행 계약해제 요구', 'date': '2014.07.15'}
#
#
#
# {'index': '364', 'category': '가사용품', 'code': '가사용품', 'title': '중고제품 표시하지 않은 컴퓨터 부품 수리비 환급 요구', 'date': '2014.07.14'}
#
#
#
# {'index': '365', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '주차장 누수로 훼손된 차량 수리비 배상 요구', 'date': '2014.07.14'}
#
#
#
# {'index': '366', 'category': '금융', 'code': '금융', 'title': '주식투자정보콘텐츠 이용계약 해지에 따른 대금 환급 요구', 'date': '2014.07.14'}
#
#
#
# {'index': '367', 'category': '의료서비스', 'code': '의료서비스', 'title': '장허혈로 입원치료 중 사망에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '368', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '인터넷 결합상품 이용대금 환급 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '369', 'category': '의료서비스', 'code': '의료서비스', 'title': '유방암 재발 진단지연으로 사망에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '370', 'category': '의료서비스', 'code': '의료서비스', 'title': '유두복원술 후 효과 미흡에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '371', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '웨딩박람회에서 계약한 신혼여행계약에 관한 청약 철회에 따른 계약금 환급 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '372', 'category': '교육서비스', 'code': '교육서비스', 'title': '2개월 이전 예식장 이용계약 취소에 따른 계약금 환급 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '373', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '엔진오일 불량으로 고장난 차량 수리비 등 배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '374', 'category': '의료서비스', 'code': '의료서비스', 'title': '안내염 진단지연으로 실명에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '375', 'category': '의료서비스', 'code': '의료서비스', 'title': '우측 경골 골절 석고고정술 후 불유합 및 부정유합 발생에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '376', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '분실로 미사용한 한일공동승차권 구입대금 환급 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '377', 'category': '의료서비스', 'code': '의료서비스', 'title': '무릎 인대 재건술 후 MRSA균 감염 및 장해 발생에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '378', 'category': '의료서비스', 'code': '의료서비스', 'title': '맹장암 진단지연에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '379', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '렌트 차량 사고 면책금 등 환급 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '380', 'category': '의료서비스', 'code': '의료서비스', 'title': '도뇨관 삽입 후 요도손상에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '381', 'category': '의료서비스', 'code': '의료서비스', 'title': '뇌경색 치료 중 사망에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '382', 'category': '스포츠·레저·취미용품', 'code': '스포츠·레저·취미용품', 'title': '골프연습장 이용 계약 해지 및 대금 환급 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '383', 'category': '의료서비스', 'code': '의료서비스', 'title': '경추 수술 후 편마비 발생에 따른 손해배상 요구', 'date': '2014.07.04'}
#
#
#
# {'index': '384', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '포장이사 도중 파손된 냉장고 손해배상 요구', 'date': '2014.06.02'}
#
#
#
# {'index': '385', 'category': '교육서비스', 'code': '교육서비스', 'title': '계약 내용과 다른 인터넷강의 수강계약의 청약철회에 따른 환급 요구', 'date': '2014.06.02'}
#
#
#
# {'index': '386', 'category': '가사용품', 'code': '가사용품', 'title': '휴업으로 인해 수리가 불가능한 가스레인지에 대한 손해배상 요구', 'date': '2014.06.02'}
#
#
#
# {'index': '387', 'category': '가사용품', 'code': '가사용품', 'title': '전자상거래를 통해 구입한 기능성 안경의 청약철회 요구', 'date': '2014.06.02'}
#
#
#
# {'index': '388', 'category': '문화·오락서비스', 'code': '문화·오락서비스', 'title': '포장이사서비스 이용 중 물품 파손에 따른 손해배상 요구', 'date': '2014.05.16'}
#
#
#
# {'index': '389', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '중고차 성능고지 부실로 인한 대금 환급 또는 손해배상 요구', 'date': '2014.05.15'}
#
#
#
# {'index': '390', 'category': '가사용품', 'code': '가사용품', 'title': '전자상거래로 구입한 옷장 청약철회 요구', 'date': '2014.05.15'}
#
#
#
# {'index': '391', 'category': '교육서비스', 'code': '교육서비스', 'title': '예식장 이용계약 해제로 인한 위약금 조정 요구', 'date': '2014.05.15'}
#
#
#
# ...
#
#
#
# {'index': '2877', 'category': '의료서비스', 'code': '의료서비스', 'title': '피부관리서비스 계약해지 요구', 'date': '2006.10.24'}
#
#
#
# {'index': '2878', 'category': '금융', 'code': '금융', 'title': '납입최고 없이 계약해지한 공제계약 원상회복 요구', 'date': '2006.10.10'}
#
#
#
# {'index': '2879', 'category': '가사용품', 'code': '가사용품', 'title': '미성년자가 노상에서 구입한 화장품 구입계약 취소 요구', 'date': '2006.09.26'}
#
#
#
# {'index': '2880', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '펜션 이용료 환급 요구', 'date': '2006.09.25'}
#
#
#
# {'index': '2881', 'category': '기타서비스', 'code': '기타서비스', 'title': '저장성향상 농약 사용 후 과피흑변된 배 배상 요구', 'date': '2006.09.20'}
#
#
#
# {'index': '2882', 'category': '의료서비스', 'code': '의료서비스', 'title': '요추간판 탈출증 수술 후 장해발생에 따른 피해보상 요구', 'date': '2006.09.15'}
#
#
#
# {'index': '2883', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '분양광고와 다른 시설물 설치로 인한 일조권 등 피해보상 요구', 'date': '2006.09.11'}
#
#
#
# {'index': '2884', 'category': '교육서비스', 'code': '교육서비스', 'title': '디지털원판 분실한 결혼식 사진 손해배상 요구', 'date': '2006.09.05'}
#
#
#
# {'index': '2885', 'category': '교육서비스', 'code': '교육서비스', 'title': '공무원시험준비 회원계약 해제 요구', 'date': '2006.08.29'}
#
#
#
# {'index': '2886', 'category': '가사용품', 'code': '가사용품', 'title': '유리그릇 파열로 다친 손가락 치료비 등 배상요구', 'date': '2006.08.18'}
#
#
#
# {'index': '2887', 'category': '교육서비스', 'code': '교육서비스', 'title': '전화어학교육 계약해지 요구', 'date': '2006.08.14'}
#
#
#
# {'index': '2888', 'category': '가사용품', 'code': '가사용품', 'title': '노상에서 구입한 화장품 청약철회 요구', 'date': '2006.08.07'}
#
#
#
# {'index': '2889', 'category': '교육서비스', 'code': '교육서비스', 'title': '질병으로 폐사한 애완견 배상 요구', 'date': '2006.08.01'}
#
#
#
# {'index': '2890', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '엔진에 하자 발생한 중고차량 수리비 보상 요구', 'date': '2006.07.11'}
#
#
#
# {'index': '2891', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '하자있는 아파트 인공지능스위치 보상 요구', 'date': '2006.07.04'}
#
#
#
# {'index': '2892', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '난방불량인 심야전기보일러 용량 증설 요구', 'date': '2006.06.20'}
#
#
#
# {'index': '2893', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '과잉 수리한 차량 수리비 환급 요구', 'date': '2006.06.13'}
#
#
#
# {'index': '2894', 'category': '가사용품', 'code': '가사용품', 'title': 'LCD 하자 노트북컴퓨터 무상수리 요구', 'date': '2006.05.23'}
#
#
#
# {'index': '2895', 'category': '의료서비스', 'code': '의료서비스', 'title': '약물 과다 투여로 C형 간염 발생에 따른 피해보상 요구', 'date': '2006.05.16'}
#
#
#
# {'index': '2896', 'category': '의료서비스', 'code': '의료서비스', 'title': '사업자 변경된 목욕탕 이용권 보상 요구', 'date': '2006.05.09'}
#
#
#
# {'index': '2897', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '주차장에서 훼손된 차량 수리비 배상요구', 'date': '2006.05.02'}
#
#
#
# {'index': '2898', 'category': '의료서비스', 'code': '의료서비스', 'title': '제왕절개술 후 혈종 발생 등에 따른 피해보상 요구', 'date': '2006.04.25'}
#
#
#
# {'index': '2899', 'category': '가사용품', 'code': '가사용품', 'title': '목욕탕에서 분실된 운동화 배상 요구', 'date': '2006.04.18'}
#
#
#
# {'index': '2900', 'category': '의료서비스', 'code': '의료서비스', 'title': '충수염 진단지연에 따른 피해보상 요구', 'date': '2006.04.04'}
#
#
#
# {'index': '2901', 'category': '의료서비스', 'code': '의료서비스', 'title': '발목골절 수술 후 MRSA 감염에 따른 피해보상 요구', 'date': '2006.03.14'}
#
#
#
# {'index': '2902', 'category': '의료서비스', 'code': '의료서비스', 'title': '좌측 족관절 치료 중 피부괴사 발생에 따른 보상 요구', 'date': '2006.02.28'}
#
#
#
# {'index': '2903', 'category': '가사용품', 'code': '가사용품', 'title': '탈색되는 가죽소파 보상 요구', 'date': '2006.02.21'}
#
#
#
# {'index': '2904', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '신청하지 않은 이동전화 부가서비스 이용요금 환급 요구', 'date': '2006.02.14'}
#
#
#
# {'index': '2905', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '운행 중 시동꺼짐현상 있는 차량 교환 요구', 'date': '2006.02.07'}
#
#
#
# {'index': '2906', 'category': '교육서비스', 'code': '교육서비스', 'title': '도로주행 교육을 받지 못한 운전학원 수강료 환급 요구', 'date': '2006.01.31'}
#
#
#
# {'index': '2907', 'category': '금융', 'code': '금융', 'title': '도난 카드 사용잔액 환급 요구', 'date': '2006.01.24'}
#
#
#
# {'index': '2908', 'category': '식료품·기호품', 'code': '식료품·기호품', 'title': '살균제 살포 후 피해 발생한 포도 보상 요구', 'date': '2006.01.17'}
#
#
#
# {'index': '2909', 'category': '교육서비스', 'code': '교육서비스', 'title': '컴퓨터학원 수강료 환급 요구', 'date': '2006.01.10'}
#
#
#
# {'index': '2910', 'category': '교육서비스', 'code': '교육서비스', 'title': '방문교육업체 폐업으로 인한 기 인출 할부금 환급 요구', 'date': '2005.12.27'}
#
#
#
# {'index': '2911', 'category': '식료품·기호품', 'code': '식료품·기호품', 'title': '피자의 이물질로 손상된 치아 보상 요구', 'date': '2005.12.05'}
#
#
#
# {'index': '2912', 'category': '교육서비스', 'code': '교육서비스', 'title': '한자학습지 구독계약 해지 요구', 'date': '2005.11.29'}
#
#
#
# {'index': '2913', 'category': '의료서비스', 'code': '의료서비스', 'title': '근육주사 후 발생된 우측 하지 통증 피해보상 요구', 'date': '2005.11.22'}
#
#
#
# {'index': '2914', 'category': '교육서비스', 'code': '교육서비스', 'title': '질병으로 폐사한 애완견 보상 요구', 'date': '2005.11.15'}
#
#
#
# {'index': '2915', 'category': '기타서비스', 'code': '기타서비스', 'title': '무인경비서비스 계약해지 요구', 'date': '2005.11.08'}
#
#
#
# {'index': '2916', 'category': '교육서비스', 'code': '교육서비스', 'title': '자동차운전전문학원 수강료 환급 요구', 'date': '2005.10.24'}
#
#
#
# {'index': '2917', 'category': '가사용품', 'code': '가사용품', 'title': '변색 및 이물 발생하는 주방용품 구입가 환급 요구', 'date': '2005.10.17'}
#
#
#
# {'index': '2918', 'category': '가사용품', 'code': '가사용품', 'title': 'PDA 구입가 환급 요구', 'date': '2005.10.11'}
#
#
#
# {'index': '2919', 'category': '의료서비스', 'code': '의료서비스', 'title': '치과치료 중 발생된 치아파절 보상 요구', 'date': '2005.09.27'}
#
#
#
# {'index': '2920', 'category': '의료서비스', 'code': '의료서비스', 'title': '퍼머 후 손상된 모발 보상 요구', 'date': '2005.09.13'}
#
#
#
# {'index': '2921', 'category': '교육서비스', 'code': '교육서비스', 'title': '어학연수 수속 대행 서비스 계약해지 요구', 'date': '2005.09.06'}
#
#
#
# {'index': '2922', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '세탁 후 경화된 점퍼 보상 요구', 'date': '2005.08.29'}
#
#
#
# {'index': '2923', 'category': '의료서비스', 'code': '의료서비스', 'title': '특정질병 수술급여금 지급 요구', 'date': '2005.08.12'}
#
#
#
# {'index': '2924', 'category': '의료서비스', 'code': '의료서비스', 'title': '충수염 오진에 따른 피해보상 요구', 'date': '2005.08.02'}
#
#
#
# {'index': '2925', 'category': '교육서비스', 'code': '교육서비스', 'title': '질병으로 폐사한 애완견 보상 요구', 'date': '2005.07.26'}
#
#
#
# {'index': '2926', 'category': '교육서비스', 'code': '교육서비스', 'title': '학원사정으로 계약해지한 전산학원 수강료 환급 요구', 'date': '2005.07.11'}
#
#
#
# {'index': '2927', 'category': '의료서비스', 'code': '의료서비스', 'title': '간암 오진에 따른 피해 보상 요구', 'date': '2005.06.14'}
#
#
#
# {'index': '2928', 'category': '의료서비스', 'code': '의료서비스', 'title': '추간판탈출증 수술 후 장애발생에 따른 보상 요구', 'date': '2005.05.31'}
#
#
#
# {'index': '2929', 'category': '의료서비스', 'code': '의료서비스', 'title': '효과없는 대머리 치료제 구입가 환급 요구', 'date': '2005.05.24'}
#
#
#
# {'index': '2930', 'category': '의료서비스', 'code': '의료서비스', 'title': '우측쇄골탈구 수술 후 감염 피해 보상 요구', 'date': '2005.05.17'}
#
#
#
# {'index': '2931', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '계약 불이행된 청소서비스 이용대금 환급 요구', 'date': '2005.05.09'}
#
#
#
# {'index': '2932', 'category': '의료서비스', 'code': '의료서비스', 'title': '슬관절 수술 후 감염발생에 따른 피해보상 요구', 'date': '2005.04.08'}
#
#
#
# {'index': '2933', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '맞춤 후 인도받지 못한 간호사복 대금 반환 요구', 'date': '2005.04.04'}
#
#
#
# {'index': '2934', 'category': '정보통신서비스', 'code': '정보통신서비스', 'title': '인터넷서비스 모뎀값 취소 요구', 'date': '2005.03.18'}
#
#
#
# {'index': '2935', 'category': '의료서비스', 'code': '의료서비스', 'title': '보철치료 후 치주염 발생 피해 보상 요구', 'date': '2005.03.14'}
#
#
#
# {'index': '2936', 'category': '교육서비스', 'code': '교육서비스', 'title': '인터넷 통신교육 서비스 계약 해지 요구', 'date': '2005.02.25'}
#
#
#
# {'index': '2937', 'category': '의료서비스', 'code': '의료서비스', 'title': '비만 관리 서비스 계약 해지 요구', 'date': '2005.02.14'}
#
#
#
# {'index': '2938', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '주유 잘못으로 하자 발생한 승용차 수리비 보상 요구', 'date': '2005.01.24'}
#
#
#
# {'index': '2939', 'category': '가사용품', 'code': '가사용품', 'title': '네비게이션 기능 불량인 PDA 보상 요구', 'date': '2004.12.21'}
#
#
#
# {'index': '2940', 'category': '교육서비스', 'code': '교육서비스', 'title': '네일아트학원 수강료 환급 요구', 'date': '2004.12.07'}
#
#
#
# {'index': '2941', 'category': '교육서비스', 'code': '교육서비스', 'title': '메이크업 강습계약 해지 요구', 'date': '2004.11.16'}
#
#
#
# {'index': '2942', 'category': '가사용품', 'code': '가사용품', 'title': '감압변 미시공으로 하자 발생한 전기온수기 보상 요구', 'date': '2004.10.12'}
#
#
#
# {'index': '2943', 'category': '교육서비스', 'code': '교육서비스', 'title': '컴퓨터통신교육계약 해지 요구', 'date': '2004.10.05'}
#
#
#
# {'index': '2944', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '카탈로그와 다르게 시공된 아파트 다락방 피해보상 요구', 'date': '2004.09.14'}
#
#
#
# {'index': '2945', 'category': '교육서비스', 'code': '교육서비스', 'title': '보육교사 강습계약 해지 요구', 'date': '2004.09.07'}
#
#
#
# {'index': '2946', 'category': '교육서비스', 'code': '교육서비스', 'title': '컴퓨터통신교육계약 해지 요구', 'date': '2004.08.31'}
#
#
#
# {'index': '2947', 'category': '가사용품', 'code': '가사용품', 'title': '구입한 사실이 없는 화장품 대금 청구 취소 요구', 'date': '2004.08.24'}
#
#
#
# {'index': '2948', 'category': '가사용품', 'code': '가사용품', 'title': '미성년자가 구입한 화장품 계약 취소 요구', 'date': '2004.08.17'}
#
#
#
# {'index': '2949', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '차량 좌·우 높이가 다른 다목적 승용차 교환 요구', 'date': '2004.08.03'}
#
#
#
# {'index': '2950', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '분양 카탈로그와 다르게 시공된 아파트 재시공 요구', 'date': '2004.07.23'}
#
#
#
# {'index': '2951', 'category': '가사용품', 'code': '가사용품', 'title': '정수기 분리부실로 누수되어 훼손된 거실바닥 등의 피해보상 요구', 'date': '2004.07.20'}
#
#
#
# {'index': '2952', 'category': '의료서비스', 'code': '의료서비스', 'title': '산후비만관리서비스 계약 해지 요구', 'date': '2004.07.13'}
#
#
#
# {'index': '2953', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '수입승용차 판매계약 불이행으로 인한 피해보상 요구', 'date': '2004.06.15'}
#
#
#
# {'index': '2954', 'category': '가사용품', 'code': '가사용품', 'title': '하자 있는 가구 환급 요구', 'date': '2004.06.01'}
#
#
#
# {'index': '2955', 'category': '교육서비스', 'code': '교육서비스', 'title': '온라인서비스 계약해지 요구', 'date': '2004.05.13'}
#
#
#
# {'index': '2956', 'category': '의류·섬유신변용품', 'code': '의류·섬유신변용품', 'title': '세탁 후 하자 발생한 여성용재킷 보상 요구', 'date': '2004.05.04'}
#
#
#
# {'index': '2957', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '다세대 주택 누수 등에 대한 하자보수 요구', 'date': '2004.04.27'}
#
#
#
# {'index': '2958', 'category': '의료서비스', 'code': '의료서비스', 'title': '대퇴부 종기 제거수술 후 발생한 염증 및 흉터 피해 보상 요구', 'date': '2004.04.19'}
#
#
#
# {'index': '2959', 'category': '교육서비스', 'code': '교육서비스', 'title': '온라인교육서비스 계약 해지 요구', 'date': '2004.04.13'}
#
#
#
# {'index': '2960', 'category': '의료서비스', 'code': '의료서비스', 'title': '피부관리서비스 청약철회 요구', 'date': '2004.03.25'}
#
#
#
# {'index': '2961', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '누수 하자보수 및 수리지연에 대한 보상요구', 'date': '2004.03.18'}
#
#
#
# {'index': '2962', 'category': '기타서비스', 'code': '기타서비스', 'title': '횡령한 취득세 및 취득세 미납으로 인한 가산금 배상 요구', 'date': '2004.03.04'}
#
#
#
# {'index': '2963', 'category': '식료품·기호품', 'code': '식료품·기호품', 'title': '포장지 표시와 다른 케일 피해 보상 요구', 'date': '2004.02.12'}
#
#
#
# {'index': '2964', 'category': '가사용품', 'code': '가사용품', 'title': '구입 23개월만에 하자 발생한 LCD모니터 무상수리 요구', 'date': '2004.01.29'}
#
#
#
# {'index': '2965', 'category': '금융', 'code': '금융', 'title': '교통사고 사망공제금 지급 요구', 'date': '2004.01.15'}
#
#
#
# {'index': '2966', 'category': '가사용품', 'code': '가사용품', 'title': '하자 발생한 MP3 Fuze2 구입대금 환급 요구', 'date': '2003.12.18'}
#
#
#
# {'index': '2967', 'category': '의료서비스', 'code': '의료서비스', 'title': '유방치료후 농양으로 악화되어 수술받은 데 대한 보상 요구', 'date': '2003.12.04'}
#
#
#
# {'index': '2968', 'category': '식료품·기호품', 'code': '식료품·기호품', 'title': '맥주의 이물로 인한 피해보상 요구', 'date': '2003.11.27'}
#
#
#
# {'index': '2969', 'category': '가사용품', 'code': '가사용품', 'title': '하자 발생한 LCD모니터 무상수리 요구', 'date': '2003.11.20'}
#
#
#
# {'index': '2970', 'category': '교육서비스', 'code': '교육서비스', 'title': '계약미이행으로 인한 수험교재 계약해제 요구', 'date': '2003.11.13'}
#
#
#
# {'index': '2971', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '수리불가한 괴탄보일러 할부항변권 수용 요구', 'date': '2003.11.06'}
#
#
#
# {'index': '2972', 'category': '가사용품', 'code': '가사용품', 'title': '하자있는 소파 구입대금 환급 요구', 'date': '2003.10.30'}
#
#
#
# {'index': '2973', 'category': '가사용품', 'code': '가사용품', 'title': '하자 발생한 수맥차단 매트 반품 요구', 'date': '2003.10.23'}
#
#
#
# {'index': '2974', 'category': '교육서비스', 'code': '교육서비스', 'title': '폐업으로 미배송된 교재 할부항변권 수용 및 부정매출 취소요구', 'date': '2003.10.16'}
#
#
#
# {'index': '2975', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '자동차용품 구입대금 환급 요구', 'date': '2003.10.09'}
#
#
#
# {'index': '2976', 'category': '금융', 'code': '금융', 'title': '명의도용에 의한 대출 무효 요구', 'date': '2003.10.02'}
#
#
#
# {'index': '2977', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '계약내용과 다른 소형승합차 교환 요구', 'date': '2003.09.04'}
#
#
#
# {'index': '2978', 'category': '교육서비스', 'code': '교육서비스', 'title': '폐업으로 미수강한 학원수강료 항변권 수용 요구', 'date': '2003.08.21'}
#
#
#
# {'index': '2979', 'category': '교육서비스', 'code': '교육서비스', 'title': '인터넷통신교육 계약해지 요구', 'date': '2003.07.24'}
#
#
#
# {'index': '2980', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '계약대로 설치되지 않은 심야전기보일러 할부금 감액 요구', 'date': '2003.07.18'}
#
#
#
# {'index': '2981', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '주유 잘못으로 하자 발생한 승용차 수리비 배상 요구', 'date': '2003.07.10'}
#
#
#
# {'index': '2982', 'category': '의료서비스', 'code': '의료서비스', 'title': '하자있는 장하지보조기 구입가 환급 요구', 'date': '2003.06.26'}
#
#
#
# {'index': '2983', 'category': '교육서비스', 'code': '교육서비스', 'title': '부실한 정보제공으로 인한 유학수속대행료 환급 요구', 'date': '2003.06.19'}
#
#
#
# {'index': '2984', 'category': '금융', 'code': '금융', 'title': '교통사고 사망보험금 지급 요구', 'date': '2003.06.12'}
#
#
#
# {'index': '2985', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '차량교환 지연에 따른 피해보상 요구', 'date': '2003.05.29'}
#
#
#
# {'index': '2986', 'category': '의료서비스', 'code': '의료서비스', 'title': '하자있는 다이어트 식품 계약 해제 요구', 'date': '2003.05.15'}
#
#
#
# {'index': '2987', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '영업 양수한 보일러의 계약금 보상 요구', 'date': '2003.05.02'}
#
#
#
# {'index': '2988', 'category': '교육서비스', 'code': '교육서비스', 'title': '오진으로 폐사한 애완견 치료비 보상 요구', 'date': '2003.04.17'}
#
#
#
# {'index': '2989', 'category': '의료서비스', 'code': '의료서비스', 'title': '분만후 화상입은 하지 보상 요구', 'date': '2003.04.10'}
#
#
#
# {'index': '2990', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '단독주택 누수로 인한 하자보수 요구', 'date': '2003.04.03'}
#
#
#
# {'index': '2991', 'category': '식료품·기호품', 'code': '식료품·기호품', 'title': '불량비닐 교체 및 보상 요구', 'date': '2003.03.27'}
#
#
#
# {'index': '2992', 'category': '기타서비스', 'code': '기타서비스', 'title': '변호사 착수금 환급 요구', 'date': '2003.03.13'}
#
#
#
# {'index': '2993', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '수리직후 화재 발생한 승합차 보상요구', 'date': '2003.02.20'}
#
#
#
# {'index': '2994', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '하자있는 승용차 보상요구', 'date': '2003.02.13'}
#
#
#
# {'index': '2995', 'category': '교육서비스', 'code': '교육서비스', 'title': '속기교재 구입 계약 청약철회 요구', 'date': '2003.01.23'}
#
#
#
# {'index': '2996', 'category': '의료서비스', 'code': '의료서비스', 'title': '치아보철후 시린것에 대한 진료비 환불 요구', 'date': '2002.12.12'}
#
#
#
# {'index': '2997', 'category': '의료서비스', 'code': '의료서비스', 'title': '충동구매한 건강식품 반품요구', 'date': '2002.12.05'}
#
#
#
# {'index': '2998', 'category': '교육서비스', 'code': '교육서비스', 'title': '계약과 다른 뉴질랜드 여름방학 영어연수 손해배상 요구', 'date': '2002.11.28'}
#
#
#
# {'index': '2999', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '작동불량 코크스보일러 환불 요구', 'date': '2002.11.14'}
#
#
#
# {'index': '3000', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '세제 사용 후 변색된 타일 변상 요구', 'date': '2002.11.07'}
#
#
#
# {'index': '3001', 'category': '의료서비스', 'code': '의료서비스', 'title': '회음 절개 부위 출혈로 인한 골반염 보상 요구', 'date': '2002.10.30'}
#
#
#
# {'index': '3002', 'category': '금융', 'code': '금융', 'title': '부정 인출된 현금 서비스 금액 보상 요구', 'date': '2002.10.24'}
#
#
#
# {'index': '3003', 'category': '교육서비스', 'code': '교육서비스', 'title': '인터넷통신교육 중도해지 요구', 'date': '2002.10.10'}
#
#
#
# {'index': '3004', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '아파트 하자 보수 요구', 'date': '2002.09.26'}
#
#
#
# {'index': '3005', 'category': '차량·승용물', 'code': '차량·승용물', 'title': '하자있는 승용차 무상수리 요구', 'date': '2002.09.12'}
#
#
#
# {'index': '3006', 'category': '의료서비스', 'code': '의료서비스', 'title': '음식 속에 들어 있던 철사로 인한 치아 치료비 배상 요구', 'date': '2002.09.05'}
#
#
#
# {'index': '3007', 'category': '의료서비스', 'code': '의료서비스', 'title': '이사로 인한 체형관리서비스 중도 해지 요구', 'date': '2002.08.14'}
#
#
#
# {'index': '3008', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '아파트 샤시 하자 보수 요구', 'date': '2002.08.08'}
#
#
#
# {'index': '3009', 'category': '금융', 'code': '금융', 'title': '증권정보 이용계약 해지 요구', 'date': '2002.07.25'}
#
#
#
# {'index': '3010', 'category': '금융', 'code': '금융', 'title': '부정 재발급 사용된 카드대금 청구취소 요구', 'date': '2002.07.18'}
#
#
#
# {'index': '3011', 'category': '토지·건물·설비', 'code': '토지·건물·설비', 'title': '심야전기 보일러 구입 계약 해지 요구', 'date': '2002.07.11'}
#
#
#
# {'index': '3012', 'category': '금융', 'code': '금융', 'title': '사용하지 않은 신용카드대금 청구취소 요구', 'date': '2002.06.26'}
#
#
#
# 3012
